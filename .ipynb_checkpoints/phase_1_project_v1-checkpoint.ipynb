# %% [markdown]
# ## Introduction

# %%
# import packages
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import sqlite3
from zipfile import ZipFile

# %%
# read in csv files
movie_gross = pd.read_csv('bom.movie_gross.csv')
movie_info = pd.read_csv('rt.movie_info.tsv',sep='\t')
movies = pd.read_csv('tmdb.movies.csv')
movie_budgets = pd.read_csv('tn.movie_budgets.csv')

# %%
# look at movie_budgets in greater detail
movie_budgets['production_budget'] = movie_budgets['production_budget'].str.strip('$')
movie_budgets['production_budget'] = movie_budgets['production_budget'].map(lambda x : re.sub(',','',x))
movie_budgets['production_budget'] = movie_budgets['production_budget'].astype(int)

movie_budgets['domestic_gross'] = movie_budgets['domestic_gross'].str.strip('$')
movie_budgets['domestic_gross'] = movie_budgets['domestic_gross'].map(lambda x : re.sub(',','',x))
movie_budgets['domestic_gross'] = movie_budgets['domestic_gross'].astype(int)

movie_budgets['worldwide_gross'] = movie_budgets['worldwide_gross'].str.strip('$')
movie_budgets['worldwide_gross'] = movie_budgets['worldwide_gross'].map(lambda x : re.sub(',','',x))
movie_budgets['worldwide_gross'] = movie_budgets['worldwide_gross'].astype(int)

movie_budgets['domestic_roi'] = movie_budgets['domestic_gross'] / movie_budgets['production_budget']
movie_budgets['worldwide_roi'] = movie_budgets['worldwide_gross'] / movie_budgets['production_budget']

# %%
# exclude movies where domestic or worldwide gross is zero
# while this data may in fact be meaningful, it may also qualify as untrustworthy
movie_budgets_posGross = movie_budgets[movie_budgets['domestic_roi'] > 0]

# given that there is only one film with either domestic or worldwide roi > 500, we will exlcude it
movie_budgets_posGross = movie_budgets[movie_budgets['domestic_roi'] < 500]

# %%
fig, ax = plt.subplots()
ax.hist(movie_budgets_posGross['worldwide_roi'],bins=500);

# %%
# from looking at the histogram, it appears the vast majority of films still appear to have ROIs less than 50
# need to more closely examine the films that have ROIs greater than 50
movie_budgets_posGross[movie_budgets_posGross['worldwide_roi'] > 50]
# Out:
#       id  release_date                               movie  production_budget  \
# 3464  65  May 25, 1977        Star Wars Ep. IV: A New Hope           11000000
# 3525  26  Jun 11, 1982           ET: The Extra-Terrestrial           10500000
# 4112  13  Jun 16, 1978                              Grease            6000000
# 4247  48  Apr 19, 2002            My Big Fat Greek Wedding            5000000
# 4248  49  Feb 24, 2017                             Get Out            5000000
# 4249  50  Jan 20, 2017                               Split            5000000
# 4424  25   Mar 9, 1994         Four Weddings and a Funeral            4500000
# 4567  68  Dec 15, 1939                  Gone with the Wind            3900000
# 4589  90  Aug 13, 1997                      The Full Monty            3500000
# 4664  65  Oct 20, 2010               Paranormal Activity 2            3000000
# 4775  76  Feb 15, 1950                          Cinderella            2900000
# 5062  63   Apr 1, 2011                           Insidious            1500000
# 5117  18  Dec 21, 1937     Snow White and the Seven Dwarfs            1488000
# 5156  57  Oct 29, 2004                                 Saw            1200000
# 5189  90  Mar 21, 2014                    Godâs Not Dead            1150000
# 5210  11  Nov 21, 1976                               Rocky            1000000
# 5211  12   Jan 6, 2012                    The Devil Inside            1000000
# 5213  14  Apr 17, 2015                          Unfriended            1000000
# 5215  16  May 24, 2006               An Inconvenient Truth            1000000
# 5219  20   May 8, 1963                              Dr. No            1000000
# 5346  47  Aug 13, 1942                               Bambi             858000
# 5357  58   Jan 1, 1971                          Billy Jack             800000
# 5372  73  Aug 11, 1973                   American Graffiti             777000
# 5406   7  Jul 14, 1999             The Blair Witch Project             600000
# 5407   8  Mar 26, 1970                           Woodstock             600000
# 5424  25   May 9, 1980                     Friday the 13th             550000
# 5428  29  Sep 26, 2008                           Fireproof             500000
# 5429  30  Nov 15, 1974                               Benji             500000
# 5430  31   Aug 6, 2004                          Open Water             500000
# 5459  60  Apr 23, 2009                                Home             500000
# 5492  93  Sep 25, 2009                 Paranormal Activity             450000
# 5507   8  Jun 11, 2004                   Napoleon Dynamite             400000
# 5525  26  Apr 15, 1983                       The Evil Dead             375000
# 5536  37  Oct 17, 1978                           Halloween             325000
# 5568  69   May 1, 1981                      Graduation Day             250000
# 5569  70   Apr 4, 1997                         Chasing Amy             250000
# 5606   7  Nov 19, 1925                      The Big Parade             245000
# 5612  13  Jul 25, 1969                    The Stewardesses             200000
# 5613  14  Mar 21, 1980                             Mad Max             200000
# 5655  56   Jan 1, 1971  Sweet Sweetback's Baad Asssss Song             150000
# 5656  57  May 16, 2007                                Once             150000
# 5665  66  Oct 18, 1974         The Texas Chainsaw Massacre             140000
# 5668  69  Nov 16, 1942                          Cat People             134000
# 5676  77   Oct 1, 1968            Night of the Living Dead             114000
# 5677  78   Feb 8, 1915               The Birth of a Nation             110000
# 5679  80  Jul 10, 2015                         The Gallows             100000
# 5680  81  Sep 29, 2006                   Facing the Giants             100000
# 5681  82   Jan 1, 1977                          Eraserhead             100000
# 5682  83   Mar 1, 1987                   Hollywood Shuffle             100000
# 5684  85   Oct 9, 1998                          The Mighty             100000
# 5706   7  Jul 10, 1998                                  Pi              68000
# 5709  10   May 7, 2004                       Super Size Me              65000
# 5715  16   Aug 9, 1995               The Brothers McMullen              50000
# 5742  43  Oct 19, 1994                              Clerks              27000
# 5746  47   Aug 1, 1997               In the Company of Men              25000
# 5752  53   Aug 1, 1991                             Slacker              23000
# 5765  66   Mar 9, 2001                             Dayereh              10000
# 5773  74  Feb 26, 1993                         El Mariachi               7000
# 5774  75   Oct 8, 2004                              Primer               7000
# 5781  82   Aug 5, 2005                   My Date With Drew               1100
#
#       domestic_gross  worldwide_gross  domestic_roi  worldwide_roi
# 3464       460998007        786598007     41.908910      71.508910
# 3525       435110554        792965326     41.439100      75.520507
# 4112       181813770        387510179     30.302295      64.585030
# 4247       241438208        374890034     48.287642      74.978007
# 4248       176040665        255367951     35.208133      51.073590
# 4249       138141585        278964806     27.628317      55.792961
# 4424        52700832        242895809     11.711296      53.976846
# 4567       198680470        390525192     50.943710     100.134665
# 4589        45950122        261249383     13.128606      74.642681
# 4664        84752907        177512032     28.250969      59.170677
# 4775        85000000        263591415     29.310345      90.893591
# 5062        54009150         99870886     36.006100      66.580591
# 5117       184925486        184925486    124.277880     124.277880
# 5156        55968727        103880027     46.640606      86.566689
# 5189        60755732         63777092     52.831071      55.458341
# 5210       117235147        225000000    117.235147     225.000000
# 5211        53262945        101759490     53.262945     101.759490
# 5213        32789645         64364198     32.789645      64.364198
# 5215        24146161         53365925     24.146161      53.365925
# 5219        16067035         59567035     16.067035      59.567035
# 5346       102797000        268000000    119.810023     312.354312
# 5357        98000000         98000000    122.500000     122.500000
# 5372       115000000        140000000    148.005148     180.180180
# 5406       140539099        248300000    234.231832     413.833333
# 5407        34505110         34505110     57.508517      57.508517
# 5424        39754601         59754601     72.281093     108.644729
# 5428        33456317         33473297     66.912634      66.946594
# 5429        31559560         31559560     63.119120      63.119120
# 5430        30500882         55518641     61.001764     111.037282
# 5459           15433         44793168      0.030866      89.586336
# 5492       107918810        194183034    239.819578     431.517853
# 5507        44540956         46122713    111.352390     115.306782
# 5525         2400000         29400000      6.400000      78.400000
# 5536        47000000         70000000    144.615385     215.384615
# 5568        23894000         23894000     95.576000      95.576000
# 5569        12006514         15155095     48.026056      60.620380
# 5606        11000000         22000000     44.897959      89.795918
# 5612        13500000         25000000     67.500000     125.000000
# 5613         8750000         99750000     43.750000     498.750000
# 5655        15200000         15200000    101.333333     101.333333
# 5656         9445857         23323631     62.972380     155.490873
# 5665        26572439         26572439    189.803136     189.803136
# 5668         4000000          8000000     29.850746      59.701493
# 5676        12087064         30087064    106.026877     263.921614
# 5677        10000000         11000000     90.909091     100.000000
# 5679        22764410         41656474    227.644100     416.564740
# 5680        10178331         10243159    101.783310     102.431590
# 5681         7000000          7014590     70.000000      70.145900
# 5682         5228617          5228617     52.286170      52.286170
# 5684         2652246          6121582     26.522460      61.215820
# 5706         3221152          4678513     47.369882      68.801662
# 5709        11529368         22233808    177.374892     342.058585
# 5715        10426506         10426506    208.530120     208.530120
# 5742         3073428          3894240    113.830667     144.231111
# 5746         2883661          2883661    115.346440     115.346440
# 5752         1227508          1227508     53.369913      53.369913
# 5765          673780           673780     67.378000      67.378000
# 5773         2040920          2041928    291.560000     291.704000
# 5774          424760           841926     60.680000     120.275143
# 5781          181041           181041    164.582727     164.582727

# %%
# connect to database and confirm schema for local reference
conn = sqlite3.connect('im.db')
df = pd.read_sql("""SELECT name FROM sqlite_master WHERE type = 'table';""", conn)
df
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %%
movie_basics = pd.read_sql("""
SELECT *
    FROM movie_basics;
""",conn)
movie_basics.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
# exclude films that do not have domestic gross data
# small number relative to the dataset and not relevant for this business question
domestic_gross = movie_gross[~movie_gross['domestic_gross'].isna()]
domestic_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
dom_gross_by_studio = domestic_gross.groupby(['studio','year']).mean()
dom_gross_by_studio.sort_values(by='domestic_gross',ascending = False)
# Out:
#              domestic_gross
# studio year
# BV     2018    3.045600e+08
#        2017    2.972750e+08
#        2015    2.268818e+08
# P/DW   2011    2.223000e+08
# BV     2016    2.208462e+08
# ...                     ...
# Grav.  2018    1.700000e+03
# Vita.  2013    1.100000e+03
# DR     2014    8.000000e+02
# BWP    2015    7.000000e+02
# W/Dim. 2017    7.000000e+02
#
# [737 rows x 1 columns]

# %%
# get table of studios with complete data by year
domestic_gross_by_year = pd.pivot_table(dom_gross_by_studio, values='domestic_gross',index='studio',columns='year')
domestic_gross_by_year = domestic_gross_by_year.dropna(axis='rows')
domestic_gross_by_year.reset_index()
domestic_gross_by_year.head()
# Out:
# year            2010          2011          2012          2013          2014  \
# studio
# BV      1.085092e+08  8.553571e+07  1.212231e+08  1.816400e+08  1.168923e+08
# CJ      5.280000e+05  2.510000e+05  4.454000e+05  2.711333e+05  1.070420e+06
# CL      2.450000e+05  7.701111e+04  1.325200e+05  8.763333e+04  3.707778e+05
# Eros    7.618750e+05  7.992714e+05  9.480667e+05  8.841214e+05  7.151111e+05
# FM      3.580000e+04  1.514286e+04  2.206667e+04  7.900000e+03  5.655980e+04
#
# year            2015          2016          2017          2018
# studio
# BV      2.268818e+08  2.208462e+08  2.972750e+08  3.045600e+08
# CJ      2.057000e+05  1.928400e+05  3.707429e+05  1.787667e+05
# CL      3.633375e+05  2.518818e+05  4.891333e+05  7.755000e+04
# Eros    2.440370e+06  5.744889e+05  3.948000e+05  4.214875e+05
# FM      6.831429e+04  5.680000e+04  8.235000e+04  9.962857e+04

# %%
# create stacked box plot of mean film domestic gross by studio
y_2010 = domestic_gross_by_year.iloc[:,0]
y_2011 = domestic_gross_by_year.iloc[:,1]
y_2012 = domestic_gross_by_year.iloc[:,2]
y_2013 = domestic_gross_by_year.iloc[:,3]
y_2014 = domestic_gross_by_year.iloc[:,4]
y_2015 = domestic_gross_by_year.iloc[:,5]
y_2016 = domestic_gross_by_year.iloc[:,6]
y_2017 = domestic_gross_by_year.iloc[:,7]
y_2018 = domestic_gross_by_year.iloc[:,8]
g_index = domestic_gross_by_year.index

fig1, ax1 = plt.subplots()

plt.bar(g_index,y_2010,color='r')
plt.bar(g_index,y_2011,bottom=y_2010,color='b')
plt.bar(g_index,y_2012,bottom=y_2010+y_2011,color='g')
plt.bar(g_index,y_2013,bottom=y_2010+y_2011+y_2012,color='c')
plt.bar(g_index,y_2014,bottom=y_2010+y_2011+y_2012+y_2013,color='m')
plt.bar(g_index,y_2015,bottom=y_2010+y_2011+y_2012+y_2013+y_2014,color='y')
plt.bar(g_index,y_2016,bottom=y_2010+y_2011+y_2012+y_2013+y_2014+y_2015,color='k')
plt.bar(g_index,y_2017,bottom=y_2010+y_2011+y_2012+y_2013+y_2014+y_2015+y_2016,color='tab:orange')
plt.bar(g_index,y_2018,bottom=y_2010+y_2011+y_2012+y_2013+y_2014+y_2015+y_2016+y_2017,color='tab:pink');

# %%
BV_movies = movie_gross[movie_gross['studio'] == 'BV']
BV_movies.head(50)
# Out:
#                                             title studio  domestic_gross  \
# 0                                     Toy Story 3     BV     415000000.0
# 1                      Alice in Wonderland (2010)     BV     334200000.0
# 7                                         Tangled     BV     200800000.0
# 13                                    Tron Legacy     BV     172100000.0
# 15            Prince of Persia: The Sands of Time     BV      90800000.0
# 34                      The Sorcerer's Apprentice     BV      63200000.0
# 44                                    Step Up 3-D     BV      42400000.0
# 70                                  The Last Song     BV      63000000.0
# 74                                         Oceans     BV      19400000.0
# 84                            Tales from Earthsea     BV         48500.0
# 95                                    Secretariat     BV      59700000.0
# 116                                  When in Rome     BV      32700000.0
# 130                                     You Again     BV      25700000.0
# 304                        Waking Sleeping Beauty     BV         80700.0
# 330   Pirates of the Caribbean: On Stranger Tides     BV     241100000.0
# 337                                        Cars 2     BV     191500000.0
# 347                                    Real Steel     BV      85500000.0
# 355                                      The Help     BV     169700000.0
# 361                             Gnomeo and Juliet     BV     100000000.0
# 364                         The Lion King (in 3D)     BV      94200000.0
# 366                                     War Horse     BV      79900000.0
# 371                                   The Muppets     BV      88600000.0
# 378                              I Am Number Four     BV      55100000.0
# 433                               Winnie the Pooh     BV      26700000.0
# 443                           Fright Night (2011)     BV      18300000.0
# 449                               Mars Needs Moms     BV      21400000.0
# 460                                  African Cats     BV      15400000.0
# 512                                          Prom     BV      10100000.0
# 727                         Marvel's The Avengers     BV     623400000.0
# 739                                         Brave     BV     237300000.0
# 740                                Wreck-It Ralph     BV     189400000.0
# 755                                   John Carter     BV      73100000.0
# 757                                       Lincoln     BV     182200000.0
# 776                  The Secret World of Arrietty     BV      19200000.0
# 805                                 Frankenweenie     BV      35300000.0
# 813                             Finding Nemo (3D)     BV      41100000.0
# 819                     Beauty and the Beast (3D)     BV      47600000.0
# 822                 The Odd Life of Timothy Green     BV      51900000.0
# 828                           Monsters, Inc. (3D)     BV      34000000.0
# 844                                    Chimpanzee     BV      29000000.0
# 889                                People Like Us     BV      12400000.0
# 1127                                       Frozen     BV     400700000.0
# 1128                                   Iron Man 3     BV     409000000.0
# 1133                          Monsters University     BV     268500000.0
# 1136                         Thor: The Dark World     BV     206400000.0
# 1139                    Oz The Great and Powerful     BV     234900000.0
# 1157                              The Lone Ranger     BV      89300000.0
# 1161                                       Planes     BV      90300000.0
# 1188                             Saving Mr. Banks     BV      83300000.0
# 1233                                 Delivery Man     BV      30700000.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 7        391000000  2010
# 13       228000000  2010
# 15       245600000  2010
# 34       152100000  2010
# 44       116900000  2010
# 70        26100000  2010
# 74        63200000  2010
# 84        68600000  2010
# 95          537000  2010
# 116       10400000  2010
# 130        6300000  2010
# 304           4200  2010
# 330      804600000  2011
# 337      370700000  2011
# 347      213800000  2011
# 355       46900000  2011
# 361       94000000  2011
# 364       91300000  2011
# 366       97700000  2011
# 371       76600000  2011
# 378       94800000  2011
# 433       23200000  2011
# 443       22700000  2011
# 449       17600000  2011
# 460       15400000  2011
# 512            NaN  2011
# 727      895500000  2012
# 739      303200000  2012
# 740      281800000  2012
# 755      211100000  2012
# 757       93100000  2012
# 776      126400000  2012
# 805       46200000  2012
# 813       28200000  2012
# 819       14400000  2012
# 822        4200000  2012
# 828       16200000  2012
# 844        5900000  2012
# 889            NaN  2012
# 1127     875700000  2013
# 1128     805800000  2013
# 1133     475700000  2013
# 1136     438200000  2013
# 1139     258399999  2013
# 1157     171200000  2013
# 1161     149000000  2013
# 1188      34600000  2013
# 1233      19300000  2013

# %%
movie_budgets.head()
movie_gross_add_budget = pd.merge(movie_gross,movie_budgets,how='left',left_on='title',right_on='movie')

# %%
# need to remove movies where there is no production budget - cannot come to any conclusions without this
movie_gross_add_budget = movie_gross_add_budget.dropna(subset=['production_budget'])

# %%
# can look at ROI of studio by year
movie_gross_studio_year = movie_gross_add_budget.groupby(['studio','year']).sum()
movie_gross_studio_year['domestic_roi_total'] = (movie_gross_studio_year['domestic_gross_y'] / 
                                                 movie_gross_studio_year['production_budget'])

# %%
movie_gross_studio_year.head()
studio_year_roi = pd.pivot_table(movie_gross_studio_year, values = ['production_budget','domestic_gross_y'], 
                                 index='studio',columns='year')
studio_year_roi = studio_year_roi.dropna(axis='rows')
studio_year_roi.head()
# Out:
#        domestic_gross_y                                           \
# year               2010          2011         2012          2013
# studio
# BV          846752076.0  1.014376e+09  781534541.0  1.491097e+09
# Focus        64567014.0  1.105614e+08  121410622.0  9.271397e+07
# Fox         736123170.0  9.373424e+08  911077035.0  1.022228e+09
# FoxS        187833172.0  1.144864e+08   65589851.0  1.091109e+08
# LGF         401504551.0  1.011150e+08  739488699.0  5.639170e+08
#
#                                                                              \
# year            2014          2015          2016         2017          2018
# studio
# BV      1.437242e+09  1.328987e+09  2.430741e+09  850244295.0  2.745169e+09
# Focus   1.188419e+08  9.694162e+07  1.657258e+08  130262115.0  9.036653e+07
# Fox     1.470344e+09  1.302526e+09  1.281602e+09  977545978.0  7.714462e+08
# FoxS    7.066039e+07  8.086272e+07  1.396039e+07  160227957.0  4.317065e+07
# LGF     4.129245e+08  4.560431e+08  2.677968e+08  249597782.0  1.400773e+08
#
#        production_budget                                           \
# year                2010          2011         2012          2013
# studio
# BV           775000000.0  1.084600e+09  785000000.0  1.058000e+09
# Focus         39000000.0  9.320000e+07  135000000.0  5.300000e+07
# Fox          757500000.0  7.020000e+08  746500000.0  1.048000e+09
# FoxS          99970000.0  1.018750e+08   12935000.0  8.945000e+07
# LGF          309787650.0  1.191000e+08  340500000.0  2.385000e+08
#
#
# year            2014          2015          2016         2017          2018
# studio
# BV      9.372000e+08  1.050100e+09  1.530000e+09  760000000.0  1.470900e+09
# Focus   9.400000e+07  6.000000e+07  2.163000e+08   81000000.0  6.000000e+07
# Fox     1.313000e+09  1.058500e+09  9.030000e+08  825000000.0  4.020000e+08
# FoxS    5.160000e+07  4.200000e+07  9.000000e+06   69500000.0  2.500000e+07
# LGF     2.950000e+08  3.545000e+08  1.650000e+08   98000000.0  1.490000e+08

# %%
# create copy of studio_year_roi with cumulative columns
studio_year_gross_cum = np.cumsum(studio_year_roi.iloc[:,0:9], axis=1)
studio_year_budg_cum = np.cumsum(studio_year_roi.iloc[:,9:19], axis=1)

#studio_year_roi_cum = studio_year_gross_cum.reset_index(drop=True) / studio_year_budg_cum.reset_index(drop=True)
studio_year_roi_cum = pd.DataFrame()

#studio_year_roi_cum = studio_year_gross_cum.reset_index(drop=True) / studio_year_budg_cum.reset_index(drop=True)
for a in np.arange(2010,2019):
    studio_year_roi_cum[a] = (studio_year_gross_cum[('domestic_gross_y', a)] / 
                                           studio_year_budg_cum[('production_budget', a)])
    
studio_year_roi_cum.index[0]
# Out:
# 'BV'

# %%
fig,ax = plt.subplots()
for b in range(studio_year_roi_cum.shape[0]):
    ax.plot(studio_year_roi_cum.columns, studio_year_roi_cum.iloc[b,], label = studio_year_roi_cum.index[b])
    
ax.legend(loc = 'lower left')
ax.set_xlabel('Year', size = 10)
ax.set_ylabel('Cumulative ROI', size=10);

# %% [markdown]
# ## Looking At Successful Studios
#
# From looking solely at the cumulative ROI of the studios for which we had continuous production data (which is not exhaustive), we can see that the studio "FoxS" had one of the highest initial ROIs and by 2018, the highest cumulative ROI. This is an appealing comparison for the trajectory of establishing a new studio because it suggests that it is possible to start with a relatively high ROI and maintain it over time, which should be the goal of Microsoft's new film unit. Looking solely at this studios movies (that is, the subset that was used in drawing the above conclusion), the goal is to see if the cumulative ROI of the studio is driven by a small number of films with high returns or achieving consistently high returns on a greater number of films.

# %%
# create a dataframe with films from the FoxS studio
FoxS_movies = movie_gross_add_budget[movie_gross_add_budget['studio'] == 'FoxS']
FoxS_movies

# look at the histogram of ROIs for specific films 
fig, ax = plt.subplots()
ax.hist(FoxS_movies['domestic_roi'],bins=20);

# %%
# since the cumulative ROI of FoxS films hovered around 1.75 for the period observed,
# look at films with ROIs greater than that level

FoxS_movies_high_roi = FoxS_movies[FoxS_movies['domestic_roi'] > 1.75]
FoxS_movies_high_roi
# Out:
#                                           title studio  domestic_gross_x  \
# 17                                   Black Swan   FoxS       107000000.0
# 141                                 Just Wright   FoxS        21500000.0
# 369                             The Descendants   FoxS        82600000.0
# 557                    Martha Marcy May Marlene   FoxS         3000000.0
# 583                               Another Earth   FoxS         1300000.0
# 782              The Best Exotic Marigold Hotel   FoxS        46400000.0
# 870                 Beasts of the Southern Wild   FoxS        12800000.0
# 904                                The Sessions   FoxS         6000000.0
# 1022                          Sound of My Voice   FoxS          408000.0
# 1173                           12 Years a Slave   FoxS        56700000.0
# 1265                                Enough Said   FoxS        17600000.0
# 1270                              Baggage Claim   FoxS        21600000.0
# 1527                   The Grand Budapest Hotel   FoxS        59300000.0
# 1953      The Second Best Exotic Marigold Hotel   FoxS        33100000.0
# 1967                                   Brooklyn   FoxS        38300000.0
# 2813                         The Shape of Water   FoxS        63900000.0
# 2821  Three Billboards Outside Ebbing, Missouri   FoxS        54500000.0
# 2876                                     Gifted   FoxS        24800000.0
# 3148                              The Favourite   FoxS        34400000.0
#
#      foreign_gross  year    id  release_date  \
# 17       222400000  2010  46.0   Dec 3, 2010
# 141          29900  2010  85.0  May 14, 2010
# 369       94700000  2011   5.0  Nov 16, 2011
# 557         548000  2011  42.0  Oct 21, 2011
# 583         456000  2011  48.0  Jul 22, 2011
# 782       90400000  2012  55.0   May 4, 2012
# 870        8300000  2012  18.0  Jun 27, 2012
# 904        3100000  2012  33.0  Oct 19, 2012
# 1022           NaN  2012  68.0  Apr 27, 2012
# 1173     131100000  2013  18.0  Oct 18, 2013
# 1265       7700000  2013  88.0  Sep 18, 2013
# 1270        887000  2013  38.0  Sep 27, 2013
# 1527     115500000  2014  27.0   Mar 7, 2014
# 1953      52900000  2015  73.0   Mar 6, 2015
# 1967      23800000  2015  79.0   Nov 4, 2015
# 2813     131400000  2017  19.0   Dec 1, 2017
# 2821     104700000  2017  59.0  Nov 10, 2017
# 2876      18200000  2017   4.0   Apr 7, 2017
# 3148      61600000  2018  39.0  Nov 23, 2018
#
#                                           movie  production_budget  \
# 17                                   Black Swan         13000000.0
# 141                                 Just Wright         12000000.0
# 369                             The Descendants         20000000.0
# 557                    Martha Marcy May Marlene          1000000.0
# 583                               Another Earth           175000.0
# 782              The Best Exotic Marigold Hotel         10000000.0
# 870                 Beasts of the Southern Wild          1800000.0
# 904                                The Sessions          1000000.0
# 1022                          Sound of My Voice           135000.0
# 1173                           12 Years a Slave         20000000.0
# 1265                                Enough Said          8000000.0
# 1270                              Baggage Claim          8500000.0
# 1527                   The Grand Budapest Hotel         31000000.0
# 1953      The Second Best Exotic Marigold Hotel         10000000.0
# 1967                                   Brooklyn         11000000.0
# 2813                         The Shape of Water         19500000.0
# 2821  Three Billboards Outside Ebbing, Missouri         12000000.0
# 2876                                     Gifted          7000000.0
# 3148                              The Favourite         15000000.0
#
#       domestic_gross_y  worldwide_gross  domestic_roi  worldwide_roi
# 17         106954678.0      331266710.0      8.227283      25.482055
# 141         21540363.0       21867665.0      1.795030       1.822305
# 369         82624961.0      175507800.0      4.131248       8.775390
# 557          2981038.0        5438911.0      2.981038       5.438911
# 583          1321194.0        2102779.0      7.549680      12.015880
# 782         46383639.0      134639780.0      4.638364      13.463978
# 870         12795746.0       23265132.0      7.108748      12.925073
# 904          6002451.0       11495204.0      6.002451      11.495204
# 1022          408015.0         429448.0      3.022333       3.181096
# 1173        56671993.0      181025343.0      2.833600       9.051267
# 1265        17550872.0       25621449.0      2.193859       3.202681
# 1270        21569509.0       22885836.0      2.537589       2.692451
# 1527        59076019.0      163981261.0      1.905678       5.289718
# 1953        33078266.0       90384306.0      3.307827       9.038431
# 1967        38322743.0       62076141.0      3.483886       5.643286
# 2813        63859435.0      195790794.0      3.274843      10.040554
# 2821        54513740.0      160191915.0      4.542812      13.349326
# 2876        24801212.0       36964656.0      3.543030       5.280665
# 3148        34366783.0       94113929.0      2.291119       6.274262

# %%
# look at ratings of those FoxS movies versus the entire movie universe
new_sub = pd.merge(FoxS_movies_high_roi, movies, how = "inner", left_on = "title", right_on = "original_title")
new_sub = new_sub.drop_duplicates(subset=['title_x'])
new_sub.sort_values(['title_x'])
# Out:
#                                       title_x studio  domestic_gross_x  \
# 9                            12 Years a Slave   FoxS        56700000.0
# 4                               Another Earth   FoxS         1300000.0
# 11                              Baggage Claim   FoxS        21600000.0
# 6                 Beasts of the Southern Wild   FoxS        12800000.0
# 0                                  Black Swan   FoxS       107000000.0
# 14                                   Brooklyn   FoxS        38300000.0
# 10                                Enough Said   FoxS        17600000.0
# 20                                     Gifted   FoxS        24800000.0
# 1                                 Just Wright   FoxS        21500000.0
# 3                    Martha Marcy May Marlene   FoxS         3000000.0
# 8                           Sound of My Voice   FoxS          408000.0
# 5              The Best Exotic Marigold Hotel   FoxS        46400000.0
# 2                             The Descendants   FoxS        82600000.0
# 21                              The Favourite   FoxS        34400000.0
# 12                   The Grand Budapest Hotel   FoxS        59300000.0
# 13      The Second Best Exotic Marigold Hotel   FoxS        33100000.0
# 7                                The Sessions   FoxS         6000000.0
# 16                         The Shape of Water   FoxS        63900000.0
# 18  Three Billboards Outside Ebbing, Missouri   FoxS        54500000.0
#
#    foreign_gross  year  id_x release_date_x  \
# 9      131100000  2013  18.0   Oct 18, 2013
# 4         456000  2011  48.0   Jul 22, 2011
# 11        887000  2013  38.0   Sep 27, 2013
# 6        8300000  2012  18.0   Jun 27, 2012
# 0      222400000  2010  46.0    Dec 3, 2010
# 14      23800000  2015  79.0    Nov 4, 2015
# 10       7700000  2013  88.0   Sep 18, 2013
# 20      18200000  2017   4.0    Apr 7, 2017
# 1          29900  2010  85.0   May 14, 2010
# 3         548000  2011  42.0   Oct 21, 2011
# 8            NaN  2012  68.0   Apr 27, 2012
# 5       90400000  2012  55.0    May 4, 2012
# 2       94700000  2011   5.0   Nov 16, 2011
# 21      61600000  2018  39.0   Nov 23, 2018
# 12     115500000  2014  27.0    Mar 7, 2014
# 13      52900000  2015  73.0    Mar 6, 2015
# 7        3100000  2012  33.0   Oct 19, 2012
# 16     131400000  2017  19.0    Dec 1, 2017
# 18     104700000  2017  59.0   Nov 10, 2017
#
#                                         movie  production_budget  \
# 9                            12 Years a Slave         20000000.0
# 4                               Another Earth           175000.0
# 11                              Baggage Claim          8500000.0
# 6                 Beasts of the Southern Wild          1800000.0
# 0                                  Black Swan         13000000.0
# 14                                   Brooklyn         11000000.0
# 10                                Enough Said          8000000.0
# 20                                     Gifted          7000000.0
# 1                                 Just Wright         12000000.0
# 3                    Martha Marcy May Marlene          1000000.0
# 8                           Sound of My Voice           135000.0
# 5              The Best Exotic Marigold Hotel         10000000.0
# 2                             The Descendants         20000000.0
# 21                              The Favourite         15000000.0
# 12                   The Grand Budapest Hotel         31000000.0
# 13      The Second Best Exotic Marigold Hotel         10000000.0
# 7                                The Sessions          1000000.0
# 16                         The Shape of Water         19500000.0
# 18  Three Billboards Outside Ebbing, Missouri         12000000.0
#
#     domestic_gross_y  ...  Unnamed: 0            genre_ids    id_y  \
# 9         56671993.0  ...        7911             [18, 36]   76203
# 4          1321194.0  ...        2633            [18, 878]   55420
# 11        21569509.0  ...        8084                 [35]  175528
# 6         12795746.0  ...        5429         [18, 14, 12]   84175
# 0        106954678.0  ...          47             [18, 53]   44214
# 14        38322743.0  ...       14276          [18, 10749]  167073
# 10        17550872.0  ...        8081      [35, 18, 10749]  209263
# 20        24801212.0  ...       20682      [18, 10751, 35]  400928
# 1         21540363.0  ...         312      [35, 18, 10749]   38093
# 3          2981038.0  ...        2656             [18, 53]   50837
# 8           408015.0  ...        2815  [878, 18, 9648, 53]   86812
# 5         46383639.0  ...        5361             [18, 35]   74534
# 2         82624961.0  ...        2610             [35, 18]   65057
# 21        34366783.0  ...       23848         [18, 36, 35]  375262
# 12        59076019.0  ...       11061             [35, 18]  120467
# 13        33078266.0  ...       14468             [18, 35]  268238
# 7          6002451.0  ...        5523      [18, 10749, 35]  113947
# 16        63859435.0  ...       20648      [18, 14, 10749]  399055
# 18        54513740.0  ...       20673             [80, 18]  359940
#
#     original_language                             original_title  popularity  \
# 9                  en                           12 Years a Slave      16.493
# 4                  en                              Another Earth      10.030
# 11                 en                              Baggage Claim       8.666
# 6                  en                Beasts of the Southern Wild       7.530
# 0                  en                                 Black Swan      13.745
# 14                 en                                   Brooklyn      12.083
# 10                 en                                Enough Said       8.722
# 20                 en                                     Gifted      16.745
# 1                  en                                Just Wright       7.047
# 3                  en                   Martha Marcy May Marlene       9.477
# 8                  en                          Sound of My Voice       7.212
# 5                  en             The Best Exotic Marigold Hotel       8.665
# 2                  en                            The Descendants      10.444
# 21                 en                              The Favourite      28.651
# 12                 en                   The Grand Budapest Hotel      18.310
# 13                 en      The Second Best Exotic Marigold Hotel       7.731
# 7                  en                               The Sessions       6.460
# 16                 en                         The Shape of Water      22.025
# 18                 en  Three Billboards Outside Ebbing, Missouri      17.808
#
#    release_date_y                                    title_y  vote_average  \
# 9      2013-10-30                           12 Years a Slave           7.9
# 4      2011-07-22                              Another Earth           6.7
# 11     2013-09-27                              Baggage Claim           5.4
# 6      2012-06-29                Beasts of the Southern Wild           6.9
# 0      2010-12-03                                 Black Swan           7.6
# 14     2015-11-04                                   Brooklyn           7.3
# 10     2013-09-18                                Enough Said           6.7
# 20     2017-04-12                                     Gifted           7.9
# 1      2010-05-14                                Just Wright           6.2
# 3      2011-10-21                   Martha Marcy May Marlene           6.7
# 8      2011-01-22                          Sound of My Voice           6.4
# 5      2012-05-25             The Best Exotic Marigold Hotel           6.9
# 2      2011-11-18                            The Descendants           6.8
# 21     2018-11-23                              The Favourite           7.7
# 12     2014-03-07                   The Grand Budapest Hotel           8.0
# 13     2015-03-06      The Second Best Exotic Marigold Hotel           6.4
# 7      2012-10-18                               The Sessions           6.9
# 16     2017-12-01                         The Shape of Water           7.2
# 18     2017-11-10  Three Billboards Outside Ebbing, Missouri           8.2
#
#    vote_count
# 9        6631
# 4         853
# 11        127
# 6         605
# 0        8374
# 14       1912
# 10        464
# 20       2035
# 1         211
# 3         413
# 8         169
# 5         756
# 2        1522
# 21       2096
# 12       8091
# 13        420
# 7         296
# 16       7224
# 18       5432
#
# [19 rows x 23 columns]

# %%
# look at rating for these movies versus those of the entire movie universe
fig, ax = plt.subplots(figsize = (15,5),ncols = 2)

# histogram of movie ratings
x = movies['vote_average']
y = new_sub['vote_average']
ax[0].hist([x,y],bins = 25, label = ["all movies", "FoxS high ROI"], density=True);
ax[0].legend(loc = "upper left")
ax[0].set_xlabel('Rating', size = 10)
ax[0].set_ylabel('Density', size = 10)

# histogram of movie popularity
x1 = movies[movies['popularity'] < 50]['popularity']
y1 = new_sub[new_sub['popularity'] < 50]['popularity']
ax[1].hist([x1,y1],bins = 25, label = ["all movies", "FoxS high ROI"], density=True);
ax[1].legend(loc = "upper right")
ax[1].set_xlabel('Popularity', size = 10)
ax[1].set_ylabel('Density', size = 10);

# %% [markdown]
# ## Conclusions from Studio Observation
#
# From looking at the histograms of movie ratings and popularity of the observed FoxS films versus the rest of the movie universe, we see that the relevant films have 1) a concentration of high ratings, and 2) higher, though still widely dispersed, popularity ratings. While neither of these results is unexpected, it suggests that we should focus on determining the underlying divers of the higher ratings to focus on making films with those attributes.
#
# From looking only at the selected films, a lot of their genre identifiers appear to be '18'. So genre seems to be a good place to start looking at some film attributes.

# %%
FoxS_titles = list(FoxS_movies_high_roi['title'])

FoxS_basics = movie_basics[movie_basics['original_title'].isin(FoxS_titles)]
FoxS_basics.sort_values(['primary_title'])

# there are some duplicates in the table due to different films of the same name - need to remove these
dupes = ['tt3184798','tt3727750','tt5838908','tt1458730']
FoxS_basics = FoxS_basics[~FoxS_basics['movie_id'].isin(dupes)]

# %%
FoxS_basics.sort_values('primary_title')
FoxS_basics_ids = list(FoxS_basics['movie_id'])
FoxS_basics_ids
# Out:
# ['tt0947798',
#  'tt1033575',
#  'tt1171222',
#  'tt1407061',
#  'tt1412386',
#  'tt1441326',
#  'tt1549572',
#  'tt1748207',
#  'tt1866249',
#  'tt2024544',
#  'tt2125435',
#  'tt2278388',
#  'tt2381111',
#  'tt2390361',
#  'tt2555736',
#  'tt4481414',
#  'tt5027774',
#  'tt5083738',
#  'tt5580390']

# %%
# get more info on persons in films
movie_knownFor = pd.read_sql("""
SELECT *
    FROM known_for;
""",conn)

movie_persons = pd.read_sql("""
SELECT *
    FROM persons;
""",conn)

movie_knownFor_FoxS = movie_knownFor[movie_knownFor['movie_id'].isin(FoxS_basics_ids)]

# %%
movie_persons_FoxS = pd.merge(movie_knownFor_FoxS, movie_persons)
movie_persons_FoxS.head()

persons_frequency = movie_persons_FoxS.value_counts(['primary_name'])

# manually examine which names have 2+ mentions in persons table
persons_frequency = persons_frequency[0:23]

key_persons = []
for c in persons_frequency.keys():
    key_persons.append(c[0])

key_persons

key_persons_all = movie_persons[movie_persons['primary_name'].isin(key_persons)]

key_persons_all
# Out:
#          person_id       primary_name  birth_year  death_year  \
# 2366     nm0370035        John Hawkes      1959.0         NaN
# 17065    nm0281765      Renée Fleming      1959.0         NaN
# 26306    nm0239267      Lillete Dubey      1953.0         NaN
# 29818    nm0110357   Graham Broadbent         NaN         NaN
# 34749   nm10084433         Seema Azmi         NaN         NaN
# 62345    nm0583796         Paul Mezey         NaN         NaN
# 67164    nm0005299      Sarah Paulson      1974.0         NaN
# 74993    nm0362051   Diana Hardcastle         NaN         NaN
# 81077    nm0780678        Nick Searcy      1959.0         NaN
# 106681   nm0003202   David G. Russell      1968.0         NaN
# 125420   nm1723954    David Kavanaugh         NaN         NaN
# 128255   nm0194446      Peter Czernin         NaN         NaN
# 134982   nm1336722       Denzil Smith         NaN         NaN
# 138575   nm1904389        Chuck Ryant         NaN         NaN
# 162345   nm2761116         Seema Azmi         NaN         NaN
# 167357   nm2648685        Mike Cahill      1979.0         NaN
# 179421   nm1779870       Brit Marling      1982.0         NaN
# 206402   nm2325520     Daniel Battsek         NaN         NaN
# 229932   nm4470559  Subhrajyoti Barat         NaN         NaN
# 288839   nm3867591         Tina Desai         NaN         NaN
# 300841   nm3544958  Jagan Ramamoorthy         NaN         NaN
# 305638   nm3832790     Raghuvir Joshi         NaN         NaN
# 361649   nm4833412       Dwight Henry      1963.0         NaN
# 437641   nm4832920  Quvenzhané Wallis      2003.0         NaN
# 552045   nm7491927         Seema Azmi         NaN         NaN
#
#                                   primary_profession
# 2366               actor,soundtrack,music_department
# 17065            actress,soundtrack,music_department
# 26306                               actress,producer
# 29818                                       producer
# 34749                                        actress
# 62345   producer,sound_department,production_manager
# 67164                    actress,soundtrack,director
# 74993                                        actress
# 81077                          actor,director,writer
# 106681                     music_department,composer
# 125420      camera_department,cinematographer,editor
# 128255                  producer,actor,miscellaneous
# 134982                                         actor
# 138575                   producer,production_manager
# 162345                                       actress
# 167357                visual_effects,editor,director
# 179421                       actress,writer,producer
# 206402                            producer,executive
# 229932                                         actor
# 288839                      actress,music_department
# 300841              producer,writer,music_department
# 305638     assistant_director,director,miscellaneous
# 361649                                         actor
# 437641                            actress,soundtrack
# 552045                                       actress
